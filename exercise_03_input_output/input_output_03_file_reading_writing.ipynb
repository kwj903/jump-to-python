# %% [markdown]
# # 파일 읽고 쓰기 학습 및 연습

# %% [markdown]
# ## 파일 생성하기

# %%
t = open("새파일.txt", 'w')
t.close()

# %%
t = open(
    "/Users/kwj903/Downloads/workspace/education/my_educate/jump-to-python/exercise_03_input_output/연습1.txt", 'w'
)
t.close()

# %% [markdown]
# - ***나 혼자 코딩!*** : 복습.txt 파일을 C:/doit 디렉터리에 만들어 보자.

# %%
# 맥북이기에 현재 디렉토리에 파일을 생성하도록 하겠다.
t = open(
    "/Users/kwj903/Downloads/workspace/education/my_educate/jump-to-python/exercise_03_input_output/복습.txt", 'w'
)
t.close()

# %% [markdown]
# ## 파일을 쓰기 모드로 열어 출력값 적기

# %%
f = open("새파일.txt", 'w')
for i in range(1, 11):
    data = "%d 번째 줄입니다.\n" % i
    f.write(data)
f.close()

# %%
for i in range(1, 11):
    data = "%d 번째 줄입니다.\n" % i
    print(data)
# Out:
# 1 번째 줄입니다.
#
# 2 번째 줄입니다.
#
# 3 번째 줄입니다.
#
# 4 번째 줄입니다.
#
# 5 번째 줄입니다.
#
# 6 번째 줄입니다.
#
# 7 번째 줄입니다.
#
# 8 번째 줄입니다.
#
# 9 번째 줄입니다.
#
# 10 번째 줄입니다.

# %% [markdown]
# ## 프로그램의 외부에 저장된 파일을 읽는 여러 가지 방법

# %% [markdown]
# ### readline 함수 사용하기

# %%
f = open("새파일.txt", 'r')
line = f.readline()
print(line)
f.close()
# Out:
# 1 번째 줄입니다.

# %%
f = open("새파일.txt", 'r')
while True:
    line = f.readline()
    if not line:break
    print(line)
f.close()
# Out:
# 1 번째 줄입니다.
#
# 2 번째 줄입니다.
#
# 3 번째 줄입니다.
#
# 4 번째 줄입니다.
#
# 5 번째 줄입니다.
#
# 6 번째 줄입니다.
#
# 7 번째 줄입니다.
#
# 8 번째 줄입니다.
#
# 9 번째 줄입니다.
#
# 10 번째 줄입니다.

# %%
while 1:
    data = input()
    if not data:break
    print(data)
# Out:
# 안녕 연습중이야.

# %% [markdown]
# ### readlines 함수 사용하기

# %%
f = open("새파일.txt", 'r')
lines = f.readlines()
for line in lines:
    print(line)
f.close()
print(lines)
print(type(lines))
# Out:
# 1 번째 줄입니다.
#
# 2 번째 줄입니다.
#
# 3 번째 줄입니다.
#
# 4 번째 줄입니다.
#
# 5 번째 줄입니다.
#
# 6 번째 줄입니다.
#
# 7 번째 줄입니다.
#
# 8 번째 줄입니다.
#
# 9 번째 줄입니다.
#
# 10 번째 줄입니다.
#
# ['1 번째 줄입니다.\n', '2 번째 줄입니다.\n', '3 번째 줄입니다.\n', '4 번째 줄입니다.\n', '5 번째 줄입니다.\n', '6 번째 줄입니다.\n', '7 번째 줄입니다.\n', '8 번째 줄입니다.\n', '9 번째 줄입니다.\n', '10 번째 줄입니다.\n']
# <class 'list'>

# %% [markdown]
# ### read 함수 사용하기

# %%
f = open("새파일.txt", 'r')
data = f.read()
print(data)
f.close()
# Out:
# 1 번째 줄입니다.
# 2 번째 줄입니다.
# 3 번째 줄입니다.
# 4 번째 줄입니다.
# 5 번째 줄입니다.
# 6 번째 줄입니다.
# 7 번째 줄입니다.
# 8 번째 줄입니다.
# 9 번째 줄입니다.
# 10 번째 줄입니다.

# %% [markdown]
# ## 파일에 새로운 내용 추가하기

# %%
f = open("새파일.txt", 'a')
for i in range(11, 20):
    data = "%d 번째 줄입니다.\n" % i
    f.write(data)
f.close()

# %%
print(open("새파일.txt", 'r').read())
# Out:
# 1 번째 줄입니다.
# 2 번째 줄입니다.
# 3 번째 줄입니다.
# 4 번째 줄입니다.
# 5 번째 줄입니다.
# 6 번째 줄입니다.
# 7 번째 줄입니다.
# 8 번째 줄입니다.
# 9 번째 줄입니다.
# 10 번째 줄입니다.
# 11 번째 줄입니다.
# 12 번째 줄입니다.
# 13 번째 줄입니다.
# 14 번째 줄입니다.
# 15 번째 줄입니다.
# 16 번째 줄입니다.
# 17 번째 줄입니다.
# 18 번째 줄입니다.
# 19 번째 줄입니다.

# %% [markdown]
# ## with문과 함께 사용하기

# %%
f = open("foo.txt", 'w')
f.write("Life is too short, you need python")
f.close()

# %%
print(open("foo.txt", 'r').readline())
# Out:
# Life is too short, you need python

# %%
with open("woojae.txt", 'w') as f:
    f.write("with문을 사용하여 파일을 열었다. 나는 곽우재다.")

# %%
print(open("woojae.txt", 'r').read())
# Out:
# with문을 사용하여 파일을 열었다. 나는 곽우재다.

# %% [markdown]
# - ***점프 투 파이썬*** : sys 모듈로 매개변수 주기

# %%
! python3 sys1.py aaa bbb ccc
# Out:
# aaa
# bbb
# ccc

# %%
! python3 sys2.py Life is too short, you need python
# Out:
# LIFE IS TOO SHORT, YOU NEED PYTHON
