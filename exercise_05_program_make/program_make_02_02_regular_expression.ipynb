# %% [markdown]
# # 정규 표현식 시작하기 학습과 연습

# %% [markdown]
# ## 정규 표현식의 기초, 메타 문자

# %% [markdown]
# 정규 표현식에서 사용하는 메타 문자에는 다음과 같은 것이 있다.
# `.^$* + ?{}[]\()`
# 정규 표현식에 위 메타 문자를 사용하면 특별한 의미를 갖게 된다.

# %% [markdown]
# ### 문자 클래스 `[]`

# %% [markdown]
# 문자 클레스로 만들어진 정규식은 '`[]` 사이의 문자들과 매치'라는 의미를 갖는다.
# 즉 정규 표현식이 `[abc]`라면 이 표현식의 의미는 'a, b, c중 한 개의 문자와 매치'
# 를 뜻한다.

# %% [markdown]
# - ***점프 투 파이썬***: 자주 사용하는 문자 클래스
# `\d, \D, \s, \S, \w, \W등이 있다. 더 자세한 설명은 검색과 LLM을 활용하자.

# %% [markdown]
# ### Dot(.)

# %% [markdown]
# 정규 표현식의 Dot(.) 메타 문자는 줄바꿈 문자인 \n을 제외한 모든 문자와 매치됨을 의미한다.

# %% [markdown]
# ### 반복(*)

# %% [markdown]
# 정규 표현식 반복(*) 메타 문자는 *가 문자 바로 앞에 있으면 그 문자가 0번 이상 반복되면 매치된다는 의미다.

# %% [markdown]
# ### 반복(+)

# %% [markdown]
# 정규 표현식 반복(+) 메타 문자는 +가 문자 바로 앞에 있으면 그 문자가 1번 이상 반복되면 매치된다는 의미다.

# %% [markdown]
# ### 반복({m,n}, ?)

# %% [markdown]
# 반복 횟수를 제한 하고 싶을 때 쓰는 메타 문자로 {m,n}은 반복 횟수가 m부터 n까지 매치한다.
# {3,}처럼 사용한다면 반복 횟수가 3회 이상인 경우고, {,3} 반복 횟수가 3회 이하를 의미한다.
# 생략된 m은 0과 동일하며, 생략된 n은 무한대(2억 개 미만)의 의미르 갖는다.

# %% [markdown]
# 1. {m}

# %% [markdown]
# `ca{2}t` : a가 2번 반복되면 매치

# %% [markdown]
# 2. {m, n}

# %% [markdown]
# `ca{2,5}t` : a가 2~5번 반복되면 매치

# %% [markdown]
# 3. {?}

# %% [markdown]
# `ab?c` : b가 0~1번 사용되면 매치

# %% [markdown]
# ## 파이썬에서 정규 표현식을 지원하는 모듈 re 모듈

# %%
# re모듈 라이브러리 사용법
import re
p = re.compile('ab*')

# %% [markdown]
# re.compile을 사용하여 정규 표현식을 컴파일한다. re.compile의 결과로 돌려주는 객체 p(컴파일된 패턴 객체)를 사용하여
# 그 이후의 작업을 수행할 것이다.

# %% [markdown]
# ## 정규식을 사용한 문자열 검색

# %%
# 기본 패턴
import re
p = re.compile('[a-z]')

# %% [markdown]
# ### match

# %% [markdown]
# match 메서드는 문자열의 처음부터 정규식과 매치되는지 조사한다.

# %%
# 기본 패턴
import re

p = re.compile("[a-z]+")

m = p.match("python")
print(m)
# Out:
# <re.Match object; span=(0, 6), match='python'>

# %%
# 기본 패턴
import re

p = re.compile("[a-z]+")

m = p.match("3 python")
print(m)
# Out:
# None

# %% [markdown]
# match의 결과로 match 객체 또는 None을 돌려주기 때문에 파이썬 정규식 프로그램은 보통 다음과 같은 흐름으로 작성한다.
# ```python
# p = re.compile(정규 표현식)
# m = p.match("조사할 문자열")
# if m:
#     print('Match found: ', m.group())
# else:
#     print('No match')
# ```

# %% [markdown]
# ### search

# %%
# 기본 패턴
import re

p = re.compile("[a-z]+")

m = p.search("python")
print(m)
# Out:
# <re.Match object; span=(0, 6), match='python'>

# %%
# 기본 패턴
import re

p = re.compile("[a-z]+")

m = p.search("3 python")
print(m)
# Out:
# <re.Match object; span=(2, 8), match='python'>

# %% [markdown]
# 이처럼 search는 문자열의 처음부터 검색하는 것이 아닌 문자열 전체를 검색한다.

# %% [markdown]
# ### findall

# %%
# 기본 패턴
import re

p = re.compile("[a-z]+")

result = p.findall("life is too short")
print(result)
# Out:
# ['life', 'is', 'too', 'short']

# %% [markdown]
# 문자열의 단어를 각각[a-z]+ 정규식과 매치해서 리스트로 돌려준다.

# %% [markdown]
# ### finditer

# %%
# 기본 패턴
import re

p = re.compile("[a-z]+")

result = p.finditer("life is too short")
print(result)

for r in result: print(r)
# Out:
# ...
# <re.Match object; span=(0, 4), match='life'>
# <re.Match object; span=(5, 7), match='is'>
# <re.Match object; span=(8, 11), match='too'>
# <re.Match object; span=(12, 17), match='short'>

# %% [markdown]
# finditer는 findall과 동일하지만 그 결과로 반복 가능한 객체를 돌려준다.
# 반복 가능한 객체가 포함하는 각각의 요소는 match 객체이다.

# %% [markdown]
# ## match 객체의 메서드

# %%
import re
p = re.compile('[a-z]+')
m = p.match("python")
print(m.group())
print(m.start())
print(m.end())
print(m.span())
# Out:
# python
# 0
# 6
# (0, 6)

# %%
import re

p = re.compile("[a-z]+")
m = p.search("3 python")
print(m.group())
print(m.start())
print(m.end())
print(m.span())
# Out:
# python
# 2
# 8
# (2, 8)

# %% [markdown]
# - ***점프 투 파이썬***: 모듈 단위로 수행하기

# %%
import re

p = re.compile('[a-z]+')
m = p.match("python")

# 위와 같은 결과를 내는 축약 방법
m = re.match('[a-z]+', "python")

# %% [markdown]
# ## 컴파일 옵션

# %% [markdown]
# 정규식을 컴파일할 때 다음 옵션을 사용할 수 있다.
# |    옵션 이름   |   약어    |                       설명                    |
# |   DOTALL | S | dot 문자(.)가 줄바꿈 문자를 포함하여 모든 문자와 매치한다. |
# | IGNORECASE | I | 대, 소문자에 관계 없이 매치한다. |
# | MULTILINE | M | 여러 줄과 매치한다. (^,$ 메타 문자의 사용과 관계가 있는 옵션이다.)  |
# | VERBOSE | X | verbose 모드를 사용한다.(정규식을 보기 편하게 만들 수도 있고 주석 등을 사용할 수도 있다.) |

# %% [markdown]
# 옵션을 사용할 때는 re.DOTALL처럼 전체 옵션 이름을 써도 되고 re.S처럼 약어를 써도 된다.

# %% [markdown]
# ### DOTALL, S

# %%
import re
p = re.compile('a.b')
m = p.match('a\nb')
print(m)
# Out:
# None

# %% [markdown]
# \n은 .메타 문자와 매치되지 않는다. 매치되게 하려면 re.DOTALL 욥션을 사용해야한다.

# %%
import re

p = re.compile("a.b", re.DOTALL)
m = p.match("a\nb")
print(m)
# Out:
# <re.Match object; span=(0, 3), match='a\nb'>

# %% [markdown]
# ### IGNORECASE, I

# %%
import re

p = re.compile('[a-z]', re.I)
print(p.match('python'))
print(p.match('Python'))
print(p.match('PYTHON'))
# Out:
# <re.Match object; span=(0, 1), match='p'>
# <re.Match object; span=(0, 1), match='P'>
# <re.Match object; span=(0, 1), match='P'>

# %% [markdown]
# ### MULTILINE, M

# %% [markdown]
# '^python'인 경우 문자열의 처음 항상 python으로 시작해야 매치되고, 만약 정규식이 'python$'이라면 문자열의 마지막은 항상 python으로 끝나야 매치된다는 의미다.

# %%
import re
p = re.compile("^python\s\w+")

data = """python one
life is too short
python two
you need python
python three"""

print(p.findall(data))
# Out:
# ['python one']

# %% [markdown]
# ^메타 문자를 문자열 전체의 처음이 아니라 각 라인의 처음으로 인식시키고 싶은 경우는 옵션 re.MULTILINE 또는 re.M이다.

# %%
import re
p = re.compile("^python\s\w+", re.MULTILINE)

data = """python one
life is too short
python two
you need python
python three"""

print(p.findall(data))
# Out:
# ['python one', 'python two', 'python three']

# %% [markdown]
# ### VERBOSE, X

# %% [markdown]
# 보기 어려운 정규식을 주석 또는 줄 단위로 구분할 수 있게 해주는 옵션은 re.VERBOSE 또는 re.X옵셥이다.

# %%
charref = re.compile(r'&[#](0[0-7]+|[0-9]+|x[0-9a-fA-F]+);')

# %% [markdown]
# 위 정규식이 쉽게 이해되는가? 이제 다음을 보자.

# %%
charref = re.compile(r"""
&[#]                        #Start of a numeric entity reference
(                           
0[0-7]+                     # Octal form
|[0-9]+                     # Decimal form
|x[0-9a-fA-F]+              # Hexadecimal form
)                       
;                           # Trailing semicolon
""", re.VERBOSE)

# %% [markdown]
# 첫 번째와 두 번째 모두 동일한 역할으 하는 코드이지만 정규식이 복잡할 경우 두 번째처럼 주석을 적고 여러 줄로 표현하는 것이 훨씬 가독성이 좋다.

# %% [markdown]
# re.VERBOSE 옵션을 사용하면 문자열에 사용된 whitespace는 컴파일할 때 제거된다(단[]안에 사용한 whitespace는 제외).
# 그리고 줄 단위로 # 기호를 사용하여 주석문을 작성할 수 있다.

# %% [markdown]
# ## 백슬래시 문제

# %% [markdown]
# 정규 표현식을 파이썬에서 사용할 때 혼란을 주는 요소가 ㅇ한 가지 있는데, 바로 백슬래시(\)이다.
# 예를 들어 어떤 파일 안에 있는 "\section"문자열을 찾기 위한 정규식을 만든다고 가정해 보자.
# `\section`
# 이 정규식은 \s 문자가 whitespace로 해석되어 의도한 대로 매치가 이루어지지 않는다.
#
# 위 표현은 다음과 동일한 의미이다.
# `[ \t\n\t\f\v]ection`  <- \s 문자가 이스케이프 코드로 해석됨
#
# 의도한 대로 매치하고 싶다면 다음과 같이 변경해야 한다.
# `\\section`
# 즉 위 정규식에서 사용한 \ 문자가 문자열 자체임을 알려주 주기 위해 백슬래시 2개를 사용하여
# 이스케이프 처리를 해야 한다.
#
# 따라서 위 정규식을 컴파일하려면 다음과 같이 작성해야 한다.
# `p = re.compile('\\section')`
# 그런데 여기에서 또 하나의 문제가 발견된다. 위처럼 정규식을 만들어서 컴파일하면 실제 파
# 이썬 정규식 엔진에는 파이썬 문자열 리터럴 규치에 따라 \\이 \로 변경되어 \section이
# 전달된다.
#
# 결국 정규식 엔진에 \\ 분자를 전달하려면 파이썬은 \\\\처럼 백슬래시를 4개나 사용해야 한다.
# `p = re.compile('\\\\section')`
# 이렇게 해야만 원하는 결과를 얻을 수 있다. 하지만 너무 복잡하지 않은가?
# 만약 위와 같이 \를 사용한 표현이 계속 반복되는 정규식이라면 너무 복잡해서 이해하기 쉽지
# 않을 것이다. 이러한 문제로 인해 파이썬 정규식에는 Raw String 규칙이 생겨나게 되었다. 즉
# 컴파일해야 하는 정규식이 Raw String임을 알려 줄 수 있도록 파이썬 문법을 만든 것이다. 그
# 방법은 다음과 같다.
# `p = re.compile(r'\\section)`
# 위와 같이 정규식 문자열 앞에 r 문자를 삽입하면 이 정규식은 Raw String 규칙에 의해서
# 백슬래시 2개 대신 1개만 써도 2개를 쓴 것과 동일한 의미를 갖게 된다.
