# %% [markdown]
# # 탭을 4개의 공백으로 바꾸기 학습과 연습

# %% [markdown]
# - 필요한 기능은? 문서 파일 읽어 들이기, 문자열 변경하기
# - 입력받는 값은? 탭을 포함한 문서 파일
# - 출력하는 값은? 탭이 공백으로 수정된 문서 파일

# %% [markdown]
# 다음과 같은 형식으로 프로그램이 수정되도록 만들것이다.
# `python tabto4.py src dst`

# %% [markdown]
# 예를 들어 a.txt 파일에 있는 탭을 4개의 공백으로 바꾸어 b.txt 파일에 저장하고 싶다면 다음과 같이 수행해야 한다.
# `python tabto4.py a.txt b.txt`

# %% [markdown]
# 1. 우선 다음과 같이 tabto4.py파일을 작성해 보자.

# %%
# tabto4.py
import sys

src = sys.argv[1]
dst = sys.argv[2]

print(src)
print(dst)

# %% [markdown]
# 2. 다음과 같이 수행했을 때 입력값이 정상으로 출력되는지 확인해 보자.

# %% [markdown]
# `python tabto4.py a.txt b.txt`

# %% [markdown]
# 3. 테스트를 위한 원본 파일(탭을 포함하는 파일)인 a.txt를 다음과 같이 작성한다. 각 단어는 탭(\t) 문자로 분리되도록 입력해야한다.

# %% [markdown]
# `Life`      `is`        `too`       `short`
# `You`       `need`      `python`

# %% [markdown]
# 4. 이제 탭 문자를 포함한 a.txt 파일을 읽어서 탭을 공백 4개로 변환할 수 있도록 코드를 변경해 보자.

# %%
# tabto4.py
import sys

src = sys.argv[1]
dst = sys.argv[2]

f = open(src)
tab_content = f.read()
f.close

space_content = tab_content.replace("\t", " "*4)
print(space_content)

# %% [markdown]
# 5. tabto4.py를 위와 같이 변경한 후 다음과 같은 명령을 수행해 보자.

# %% [markdown]
# `python tabto4.py a.txt b.txt`

# %% [markdown]
# 6. 이제 변경된 내용을 b.txt파일에 저장할 수 있도록 다음과 같이 프로그램을 변경해 보자.

# %%
# tabto4.py

import sys

src = sys.argv[1]
dst = sys.argv[2]

f = open(src)
tab_content = f.read()
f.close

space_content = tab_content.replace("\t", " " * 4)

f = open(dst, "w")
f.write(space_content)
f.close()

# %% [markdown]
# 7. 프로그램을 실행하기 위해 다음 명령을 수행한다.

# %% [markdown]
# `python tabto4.py a.txt b.txt`
