# %% [markdown]
# # whil문 학습과 연습

# %% [markdown]
# ## while문의 기본 구조

# %%
treeHit = 0
while treeHit < 10:
    treeHit = treeHit + 1
    print("나무를 %d번 찍혔습니다." % treeHit)
    if treeHit == 10:
        print("나무가 넘어갑니다.")
# Out:
# 나무를 1번 찍혔습니다.
# 나무를 2번 찍혔습니다.
# 나무를 3번 찍혔습니다.
# 나무를 4번 찍혔습니다.
# 나무를 5번 찍혔습니다.
# 나무를 6번 찍혔습니다.
# 나무를 7번 찍혔습니다.
# 나무를 8번 찍혔습니다.
# 나무를 9번 찍혔습니다.
# 나무를 10번 찍혔습니다.
# 나무가 넘어갑니다.

# %% [markdown]
# ## while문 만들기

# %%
prompt = '''
1. Add
2. Del
3. List
4. Quit

Enter number: '''
number = 0
while number != 4:
    print(prompt)
    number =int(input())
# Out:
# 1. Add
# 2. Del
# 3. List
# 4. Quit
#
# Enter number:
#
# 1. Add
# 2. Del
# 3. List
# 4. Quit
#
# Enter number:

# %% [markdown]
# ## while문 강제로 빠져나가기

# %%
coffee = 10
money = 300
while money:
    print("돈을 받았으니 커피를 줍니다.")
    coffee -= 1
    print("남은 커피의 양은 %d개입니다." % coffee)
    if not coffee:
        print("커피가 다 떨어졌습니다. 판매를 중지합니다.")
        break
# Out:
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 9개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 8개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 7개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 6개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 5개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 4개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 3개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 2개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 1개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 0개입니다.
# 커피가 다 떨어졌습니다. 판매를 중지합니다.

# %%
coffee = 10
while True:
    money = int(input("돈을 넣어 주세요: "))
    if money == 300:
        print("커피를 줍니다.")
        coffee -= 1
        print("남은 커피의 양은 %d개 입니다." % coffee)
    elif money > 300:
        print("거스름돈 %d을 주고 커피를 줍니다." % (money - 300))
    else:
        print("돈을 다시 돌려주고 커피를 주지 않습니다.")
        print("남은 커피의 양은 %d개 입니다." % coffee)
    if not coffee:
        print("커피가 다 떨어졌습니다. 판매를 중지합니다.")
        break
# Out:
# 돈을 다시 돌려주고 커피를 주지 않습니다.
# 남은 커피의 양은 10개 입니다.
# 거스름돈 300을 주고 커피를 줍니다.
# 커피를 줍니다.
# 남은 커피의 양은 9개 입니다.
# 커피를 줍니다.
# 남은 커피의 양은 8개 입니다.
# 커피를 줍니다.
# 남은 커피의 양은 7개 입니다.
# 커피를 줍니다.
# 남은 커피의 양은 6개 입니다.
# 커피를 줍니다.
# 남은 커피의 양은 5개 입니다.
# 커피를 줍니다.
# 남은 커피의 양은 4개 입니다.
# 커피를 줍니다.
# 남은 커피의 양은 3개 입니다.
# 커피를 줍니다.
# 남은 커피의 양은 2개 입니다.
# 커피를 줍니다.
# 남은 커피의 양은 1개 입니다.
# 커피를 줍니다.
# 남은 커피의 양은 0개 입니다.
# 커피가 다 떨어졌습니다. 판매를 중지합니다.

# %% [markdown]
# ## while문의 맨 처음으로 돌아가기

# %%
a = 0
while a < 10:
    a += 1
    if a % 2 == 0 : continue
    print(a)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# - ***나 혼자 코딩*** : 1부터 10까지의 숫자 중에서 3의 배수를 뺀 나머지 값을 출력해 보자

# %%
number = 0
while True:
    number += 1
    if number % 3 != 0:
        print(number)
    if number == 10: break
# Out:
# 1
# 2
# 4
# 5
# 7
# 8
# 10

# %% [markdown]
# ## 무한 루프

# %%
import time
while True:

    print("Ctr + C를 툴러야 while문을 빠져 나갈 수 있습니다.")
    time.sleep(3)
    print("이건 주피터노트북커널로 실행한 무한루프이기 때문에 중지를 눌러주어야합니다.")
# Out:
# Ctr + C를 툴러야 while문을 빠져 나갈 수 있습니다.
# 이건 주피터노트북커널로 실행한 무한루프이기 때문에 중지를 눌러주어야합니다.
# Ctr + C를 툴러야 while문을 빠져 나갈 수 있습니다.
# 이건 주피터노트북커널로 실행한 무한루프이기 때문에 중지를 눌러주어야합니다.
# Ctr + C를 툴러야 while문을 빠져 나갈 수 있습니다.
# 이건 주피터노트북커널로 실행한 무한루프이기 때문에 중지를 눌러주어야합니다.
# Ctr + C를 툴러야 while문을 빠져 나갈 수 있습니다.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 5
#       2 while True:
#       4     print("Ctr + C를 툴러야 while문을 빠져 나갈 수 있습니다.")
# ----> 5     time.sleep(3)
#       6     print("이건 주피터노트북커널로 실행한 무한루프이기 때문에 중지를 눌러주어야합니다.")
#
# KeyboardInterrupt:
